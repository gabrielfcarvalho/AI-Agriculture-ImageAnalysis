# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

folder_path = "/content/drive/MyDrive/TG/sorgo_256/20160613_F54_training_256x256"
txt_count = 0
png_count = 0
for file_name in os.listdir(folder_path):
    if file_name.endswith(".txt"):
        txt_count += 1
    elif file_name.endswith(".png"):
        png_count += 1

print(f"Number of .txt files: {txt_count}")
print(f"Number of .png files: {png_count}")
# Out:
# Number of .txt files: 0
# Number of .png files: 50003

# %%
import cv2
from google.colab.patches import cv2_imshow

# Load an image from file
image_path = '/content/drive/MyDrive/TG/sorgo_256/20160613_F54_training_256x256/20160613_F54_training_s1pev6579h7m0y2wmtv1wv.png'
image = cv2.imread(image_path)

# Check if the image was loaded successfully
if image is None:
    print("Error: Could not open the image file.")
else:
    # Display the image in a window
    cv2_imshow(image)

    # Wait for a key press and close the window
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F18F13C7C70>

# %%
import os

# Substitua 'your_folder_path' pelo caminho da pasta onde deseja deletar os arquivos .txt
folder_path = "/content/drive/MyDrive/TG/sorgo_256/20160613_F54_validation_256x256"

# Iterar pelos arquivos e deletar os arquivos .txt
for file in os.listdir(folder_path):
    if file.endswith(".txt"):
        file_path = os.path.join(folder_path, file)
        os.remove(file_path)
        print(f"Arquivo {file} removido com sucesso.")
# Out:
# Arquivo 20160613_F54_validation_9o9xtc4glvm91yymnzqxlv.txt removido com sucesso.
# Arquivo 20160613_F54_validation_ximw6ahxew28loibn808d4.txt removido com sucesso.
# Arquivo 20160613_F54_validation_ikc58rrn0xs0g6ofe19on6.txt removido com sucesso.
# Arquivo 20160613_F54_validation_vnnmnui2z9bj21lshhs1ou.txt removido com sucesso.
# Arquivo 20160613_F54_validation_76htlgok7ekk6fff8c90mk.txt removido com sucesso.
# Arquivo 20160613_F54_validation_n8qni4zt4hse6kca1elj65.txt removido com sucesso.
# Arquivo 20160613_F54_validation_mq2tumpkzmw6word9w91ua.txt removido com sucesso.
# Arquivo 20160613_F54_validation_eolyufh9dj2nh9w25n7u6z.txt removido com sucesso.
# Arquivo 20160613_F54_validation_wmz7ggmz28kxdgy8yj9gcu.txt removido com sucesso.
# Arquivo 20160613_F54_validation_br68if5rrb9va0acmjtp35.txt removido com sucesso.
# Arquivo 20160613_F54_validation_cxdllsebvx8vml9fr0mb08.txt removido com sucesso.
# Arquivo 20160613_F54_validation_crtkxdq6xor8ohvkawbhul.txt removido com sucesso.
# ...
