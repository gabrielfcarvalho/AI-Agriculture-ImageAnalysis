# %% [markdown]
# # **Verificar GPU**

# %%
# !nvidia-smi
# Out:
# Thu May  4 19:22:37 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   65C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # **Montando o Drive**

# %%
# Coloca os arquivos do google drive disponíveis para serem usados pelo colab

from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Clonando o Repositório e Instalando as Dependências**

# %%
! pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.0/566.0 kB 24.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.3/203.3 kB 27.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **Testando o Modelo nas Imagens de Teste e no Vídeo**

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/TG/arquiteturas/Ultralytics/YOLOv8/YOLOv8x_tuned/Pesos_Treinamento/best.pt')  # load a custom model
results = model.predict('/content/drive/MyDrive/TG/arquiteturas/Ultralytics/sorghumfield.v3-416x416_augmented.yolov8/test/images', save=True, imgsz=416, conf=0.5, hide_labels=True, hide_conf=True)
# Out:
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# WARNING ⚠️ 'hide_conf' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_conf' instead.
#
# image 1/32 /content/drive/MyDrive/TG/arquiteturas/Ultralytics/sorghumfield.v3-416x416_augmented.yolov8/test/images/testing_17_png.rf.2cbfe9d703e1046a6bd252360814d983.jpg: 416x416 10 sorghum_plants, 50.9ms
# image 2/32 /content/drive/MyDrive/TG/arquiteturas/Ultralytics/sorghumfield.v3-416x416_augmented.yolov8/test/images/testing_20_png.rf.b42eb18de55a877b0e327be4c2596bf9.jpg: 416x416 9 sorghum_plants, 50.9ms
# image 3/32 /content/drive/MyDrive/TG/arquiteturas/Ultralytics/sorghumfield.v3-416x416_augmented.yolov8/test/images/testing_25_png.rf.c782ccc3452d9c73651d90080c7fa248.jpg: 416x416 6 sorghum_plants, 50.9ms
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/TG/arquiteturas/Ultralytics/YOLOv8/YOLOv8x_tuned/Pesos_Treinamento/best.pt')
results = model.track(source="/content/drive/MyDrive/TG/arquiteturas/Ultralytics/YOLOv8/20160613-f54-training-007ln5iotrojz4sf7y5k2y_MBR3wQYk.mp4", conf=0.3, iou=0.5, save=True, hide_labels=True, hide_conf=True)
# Out:
# requirements: YOLOv8 requirement "lap>=0.4" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 71.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for lap: filename=lap-0.4.0-cp310-cp310-linux_x86_64.whl size=1655282 sha256=808372a4abf5b22df840a1562c59232a711f3cdfaee60aa7b60ab43c35d2467d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qq0vnx3i/wheels/00/42/2e/9dfe19270eea279d79e84767ff0d7b8082c3bf776cad00e83d
# Successfully built lap
# ...
#
# requirements: 1 package updated per ['lap>=0.4']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# ...

# %% [markdown]
# # **Salvando as Bounding Boxes para Usar nos Outros Códigos (Basta escolher *xyxy (topo esquerdo e baixo direito) ou xywh (centro, largura e altura)*)**

# %%
bounding_boxes_xywh = [result.boxes.xywh for result in results]

print("Bounding boxes for image 1:", bounding_boxes_xywh[0])
# Out:
# Bounding boxes for image 1: tensor([[281.0857, 161.4280,  59.6277, 322.0080],
#         [376.4540, 156.8315,  56.6536, 283.4524],
#         [191.9488, 161.8454,  55.6736, 321.9173],
#         [378.5609, 386.7907,  52.7142,  58.4186],
#         [ 95.5935, 150.5902,  53.3537, 300.1929],
#         [283.1572, 386.4635,  48.5226,  59.0730],
#         [ 96.7655, 386.8226,  57.0319,  58.3548],
#         [ 16.6350, 240.3738,  32.7101, 345.7437],
#         [192.6547, 384.4404,  51.5413,  63.0710],
#         [ 17.2421,  24.7319,  34.4842,  49.4577]], device='cuda:0')

# %%
import torch
import numpy as np

#torch.save(bounding_boxes_xywh, '/content/drive/MyDrive/TG/arquiteturas/Ultralytics/YOLOv8/calculos/bounding_boxes_xywh.pt')

bounding_boxes_xywh = torch.load('/content/drive/MyDrive/TG/arquiteturas/Ultralytics/YOLOv8/calculos/bounding_boxes_xywh.pt')

print(bounding_boxes_xywh[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-3d363e4dc59e> in <cell line: 8>()
#       6 bounding_boxes_xywh = torch.load('/content/drive/MyDrive/TG/arquiteturas/Ultralytics/YOLOv8/calculos/bounding_boxes_xywh.pt')
#       7
# ----> 8 print(bounding_boxes_xywh[0].numpy())
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.
